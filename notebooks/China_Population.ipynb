# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import regex as re
import seaborn as sns

# %%
# Import the data
df = pd.read_csv("../data/Chinas_Population_En.csv")  #..(relative path, goes to the parent directory) vs. C:Users (absolute path)

# %% [markdown]
# ## China's Population by urban/rural and gender
#
# #### China's Population by classified by gender and urban/rural since 1949
#
# Note: Population data in 1981 and before are household registration statistics; The data of 1982, 1990, 2000, 2010 and 2020 are calculated from the census data of the same year. Data for the remaining years were derived from annual population sampling surveys. Active servicemen are included in the total population and population by sex, and active servicemen are included in the urban population by urban and rural population.
#
# Source: National Bureau of Statistics. Link: https://data.stats.gov.cn/

# %% [markdown]
# My note: Total population = Male population + Female population
# <br>The total population of 141260(ten thousand) = 1412600000

# %%
df
# Out:
#     Year  Total population (ten thousand)  Male population (ten thousand)
# 0   2022                           141175                           72206  \
# 1   2021                           141260                           72311
# 2   2020                           141212                           72357
# 3   2019                           141008                           72039
# 4   2018                           140541                           71864
# ..   ...                              ...                             ...
# 69  1953                            58796                           30468
# 70  1952                            57482                           29833
# 71  1951                            56300                           29231
# 72  1950                            55196                           28669
# 73  1949                            54167                           28145
#
#     Female population (ten thousand)  Urban population (ten thousand)
# ...

# %% [markdown]
# ## Plotting

# %%
# Plotting
plt.figure(figsize=(10, 5))

plt.plot(df["Year"], df["Total population (ten thousand)"], label='Total Population')
plt.plot(df["Year"], df["Male population (ten thousand)"], label='Male Population')
plt.plot(df["Year"], df["Female population (ten thousand)"], label='Female Population')
plt.plot(df["Year"], df["Urban population (ten thousand)"], label='Urban Population')
plt.plot(df["Year"], df["Rural population (ten thousand)"], label='Rural Population')

plt.xlabel("Year")
plt.ylabel("Population (ten thousand)")
plt.title("Population Over the Years")
plt.legend()
plt.grid(True)

plt.show()
